# %%
#필요한 라이브러리를 로드합니다. 
import os
import math
import numpy as np
import tensorflow as tf

from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from glob import glob

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize

def build_augmentation(is_train=True):
    if is_train:    # 훈련용 데이터일 경우
        return Compose([
                        HorizontalFlip(p=0.5),    # 50%의 확률로 좌우대칭
                        RandomSizedCrop(         # 50%의 확률로 RandomSizedCrop
                            min_max_height=(300, 370),
                            w2h_ratio=370/1242,
                            height=224,
                            width=224,
                            p=0.5
                            ),
                        Resize(              # 입력이미지를 224X224로 resize
                            width=224,
                            height=224
                            )
                        ])
    return Compose([      # 테스트용 데이터일 경우에는 224X224로 resize만 수행합니다. 
                    Resize(
                        width=224,
                        height=224
                        )
                    ])

# %%
import os

dir_path = os.getenv('HOME')+'/aiffel/semantic_segmentation/data/training'

augmentation = build_augmentation()
input_images = glob(os.path.join(dir_path, "image_2", "*.png"))

# 훈련 데이터셋에서 5개만 가져와 augmentation을 적용해 봅시다.  
plt.figure(figsize=(12, 20))
for i in range(5):
    image = imread(input_images[i]) 
    image_data = {"image":image}
    resized = augmentation(**image_data, is_train=False)
    processed = augmentation(**image_data)
    plt.subplot(5, 2, 2*i+1)
    plt.imshow(resized["image"])  # 왼쪽이 원본이미지
    plt.subplot(5, 2, 2*i+2)
    plt.imshow(processed["image"])  # 오른쪽이 augment된 이미지
    plt.show()

# %%
class KittiGenerator(tf.keras.utils.Sequence):
    '''
    KittiGenerator는 tf.keras.utils.Sequence를 상속받습니다.
    우리가 KittiDataset을 원하는 방식으로 preprocess하기 위해서 Sequnce를 커스텀해 사용합니다.
    '''
    def __init__(self, 
                 dir_path,
                 batch_size=16,
                 img_size=(224, 224, 3),
                 output_size=(224, 224),
                 is_train=True,
                 augmentation=None):
        '''
        dir_path: dataset의 directory path입니다.
        batch_size: batch_size입니다.
        img_size: preprocess에 사용할 입력이미지의 크기입니다.
        output_size: ground_truth를 만들어주기 위한 크기입니다.
        is_train: 이 Generator가 학습용인지 테스트용인지 구분합니다.
        augmentation: 적용하길 원하는 augmentation 함수를 인자로 받습니다.
        '''
        self.dir_path = dir_path
        self.batch_size = batch_size
        self.is_train = is_train
        self.dir_path = dir_path
        self.augmentation = augmentation
        self.img_size = img_size
        self.output_size = output_size

        # load_dataset()을 통해서 kitti dataset의 directory path에서 라벨과 이미지를 확인합니다.
        self.data = self.load_dataset()

    def load_dataset(self):
        # kitti dataset에서 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수입니다.
        # 이때 is_train에 따라 test set을 분리해서 load하도록 해야합니다.
        input_images = glob(os.path.join(self.dir_path, "image_2", "*.png"))
        label_images = glob(os.path.join(self.dir_path, "semantic", "*.png"))
        input_images.sort()
        label_images.sort()
        assert len(input_images) == len(label_images)
        data = [ _ for _ in zip(input_images, label_images)]

        if self.is_train:
            return data[:-30]
        
        return data[-30:]
    
    def __len__(self):
        # Generator의 length로서 전체 dataset을 batch_size로 나누고 소숫점 첫째자리에서 올림한 값을 반환합니다.
        return math.ceil(len(self.data) / self.batch_size)

    def __getitem__(self, index):
        # 입력과 출력을 만듭니다.
        # 입력은 resize및 augmentation이 적용된 input image이고 
        # 출력은 semantic label입니다.
        batch_data = self.data[
                               index*self.batch_size:
                               (index + 1)*self.batch_size
                               ]
        inputs = np.zeros([self.batch_size, *self.img_size])
        outputs = np.zeros([self.batch_size, *self.output_size])
        
        for i, data in enumerate(batch_data):
            input_img_path, output_path = data
            _input = imread(input_img_path)
            _output = imread(output_path)
            _output = (_output==7).astype(np.uint8)*1
            data = {
                "image": _input,
                "mask": _output,
                }
            augmented = self.augmentation(**data)
            inputs[i] = augmented["image"]/255
            outputs[i] = augmented["mask"]
        
        return inputs, outputs

    def on_epoch_end(self):
        # 한 epoch가 끝나면 실행되는 함수입니다. 학습중인 경우에 순서를 random shuffle하도록 적용한 것을 볼 수 있습니다.
        self.indexes = np.arange(len(self.data))
        if self.is_train == True :
            np.random.shuffle(self.indexes)
        
        return self.indexes

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)
        
train_generator = KittiGenerator(
    dir_path, 
    augmentation=augmentation,
)

test_generator = KittiGenerator(
    dir_path, 
    augmentation=test_preproc,
    is_train=False
)

# %%
def build_model(input_shape=(224, 224, 3)):
    inputs = Input(input_shape)

    #Contracting Path
    conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool4)  
    conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv5)

    #Expanding Path
    drop5 = Dropout(0.5)(conv5)
    up6 = Conv2D(512, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(drop5)) 
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv6)
    up7 = Conv2D(256, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv7)
    up8 = Conv2D(128, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv8)
    up9 = Conv2D(64, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)  
    conv9 = Conv2D(2, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)     
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

    model = Model(inputs = inputs, outputs = conv10)
    return model

model = build_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 112, 112, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 28, 28, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 14, 14, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 14, 14, 1024) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 28, 28, 1024) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 28, 1024) 0           dropout[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 56, 56, 512)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 56, 56, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 112, 112, 256 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 112, 112, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 112, 112, 256 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 112, 112, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 112, 112, 128 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 224, 224, 128 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 224, 224, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 224, 224, 128 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 224, 224, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 224, 224, 64) 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 224, 224, 2)  1154        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 224, 224, 1)  3           conv2d_22[0][0]
# ==================================================================================================
# Total params: 31,032,837
# Trainable params: 31,032,837
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy')
model.fit_generator(
     generator=train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

model_path = dir_path + '/seg_model_unet.h5'
model.save(model_path)  #학습한 모델을 저장해 주세요.
# Out:
# /home/aiffel-dj31/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 11/11 [==============================] - 50s 763ms/step - loss: 0.6158 - val_loss: 0.5166
# Epoch 2/100
# 11/11 [==============================] - 8s 686ms/step - loss: 0.4282 - val_loss: 0.3974
# Epoch 3/100
# 11/11 [==============================] - 8s 692ms/step - loss: 0.3365 - val_loss: 0.3263
# Epoch 4/100
# 11/11 [==============================] - 8s 690ms/step - loss: 0.2810 - val_loss: 0.3183
# Epoch 5/100
# 11/11 [==============================] - 8s 689ms/step - loss: 0.3198 - val_loss: 0.3195
# Epoch 6/100
# 11/11 [==============================] - 8s 696ms/step - loss: 0.2889 - val_loss: 0.2791
# Epoch 7/100
# 11/11 [==============================] - 8s 711ms/step - loss: 0.2457 - val_loss: 0.2743
# Epoch 8/100
# 11/11 [==============================] - 8s 728ms/step - loss: 0.2080 - val_loss: 0.2834
# Epoch 9/100
# 11/11 [==============================] - 8s 724ms/step - loss: 0.2162 - val_loss: 0.2576
# Epoch 10/100
# 11/11 [==============================] - 8s 680ms/step - loss: 0.2141 - val_loss: 0.2535
# Epoch 11/100
# 11/11 [==============================] - 8s 674ms/step - loss: 0.2099 - val_loss: 0.2581
# Epoch 12/100
# 11/11 [==============================] - 7s 665ms/step - loss: 0.2136 - val_loss: 0.2279
# Epoch 13/100
# 11/11 [==============================] - 8s 719ms/step - loss: 0.1865 - val_loss: 0.2722
# Epoch 14/100
# 11/11 [==============================] - 8s 677ms/step - loss: 0.1806 - val_loss: 0.2484
# Epoch 15/100
# 11/11 [==============================] - 8s 677ms/step - loss: 0.2203 - val_loss: 0.2804
# Epoch 16/100
# 11/11 [==============================] - 8s 670ms/step - loss: 0.1916 - val_loss: 0.2515
# Epoch 17/100
# 11/11 [==============================] - 8s 683ms/step - loss: 0.1585 - val_loss: 0.2258
# Epoch 18/100
# 11/11 [==============================] - 8s 680ms/step - loss: 0.1498 - val_loss: 0.2193
# Epoch 19/100
# 11/11 [==============================] - 8s 686ms/step - loss: 0.1649 - val_loss: 0.2183
# Epoch 20/100
# 11/11 [==============================] - 8s 684ms/step - loss: 0.1529 - val_loss: 0.1998
# Epoch 21/100
# 11/11 [==============================] - 8s 704ms/step - loss: 0.1835 - val_loss: 0.2658
# Epoch 22/100
# 11/11 [==============================] - 8s 711ms/step - loss: 0.1846 - val_loss: 0.2700
# Epoch 23/100
# 11/11 [==============================] - 8s 705ms/step - loss: 0.1591 - val_loss: 0.2776
# Epoch 24/100
# 11/11 [==============================] - 8s 712ms/step - loss: 0.2195 - val_loss: 0.2026
# Epoch 25/100
# 11/11 [==============================] - 8s 706ms/step - loss: 0.1789 - val_loss: 0.2049
# Epoch 26/100
# 11/11 [==============================] - 8s 735ms/step - loss: 0.1604 - val_loss: 0.1987
# Epoch 27/100
# 11/11 [==============================] - 8s 717ms/step - loss: 0.1634 - val_loss: 0.1958
# Epoch 28/100
# 11/11 [==============================] - 8s 702ms/step - loss: 0.1752 - val_loss: 0.2117
# Epoch 29/100
# 11/11 [==============================] - 8s 693ms/step - loss: 0.1586 - val_loss: 0.2621
# Epoch 30/100
# 11/11 [==============================] - 8s 692ms/step - loss: 0.1639 - val_loss: 0.2421
# Epoch 31/100
# 11/11 [==============================] - 8s 693ms/step - loss: 0.1587 - val_loss: 0.3215
# Epoch 32/100
# 11/11 [==============================] - 8s 694ms/step - loss: 0.1650 - val_loss: 0.2389
# Epoch 33/100
# 11/11 [==============================] - 8s 696ms/step - loss: 0.1729 - val_loss: 0.2059
# Epoch 34/100
# 11/11 [==============================] - 8s 694ms/step - loss: 0.1536 - val_loss: 0.1818
# Epoch 35/100
# 11/11 [==============================] - 8s 692ms/step - loss: 0.1529 - val_loss: 0.1764
# Epoch 36/100
# 11/11 [==============================] - 8s 693ms/step - loss: 0.1395 - val_loss: 0.1933
# Epoch 37/100
# 11/11 [==============================] - 8s 730ms/step - loss: 0.1320 - val_loss: 0.2038
# Epoch 38/100
# 11/11 [==============================] - 8s 728ms/step - loss: 0.1552 - val_loss: 0.1750
# Epoch 39/100
# 11/11 [==============================] - 8s 736ms/step - loss: 0.1566 - val_loss: 0.1786
# Epoch 40/100
# 11/11 [==============================] - 8s 730ms/step - loss: 0.1395 - val_loss: 0.1816
# Epoch 41/100
# 11/11 [==============================] - 8s 727ms/step - loss: 0.1383 - val_loss: 0.1906
# Epoch 42/100
# 11/11 [==============================] - 8s 725ms/step - loss: 0.1271 - val_loss: 0.2104
# Epoch 43/100
# 11/11 [==============================] - 8s 733ms/step - loss: 0.1262 - val_loss: 0.2552
# Epoch 44/100
# 11/11 [==============================] - 8s 727ms/step - loss: 0.1408 - val_loss: 0.1739
# Epoch 45/100
# 11/11 [==============================] - 8s 729ms/step - loss: 0.1242 - val_loss: 0.1697
# Epoch 46/100
# 11/11 [==============================] - 8s 727ms/step - loss: 0.1217 - val_loss: 0.1687
# Epoch 47/100
# 11/11 [==============================] - 8s 726ms/step - loss: 0.1256 - val_loss: 0.1615
# Epoch 48/100
# 11/11 [==============================] - 8s 701ms/step - loss: 0.1232 - val_loss: 0.1764
# Epoch 49/100
# 11/11 [==============================] - 8s 698ms/step - loss: 0.1162 - val_loss: 0.1677
# Epoch 50/100
# 11/11 [==============================] - 8s 671ms/step - loss: 0.1381 - val_loss: 0.1723
# Epoch 51/100
# 11/11 [==============================] - 7s 661ms/step - loss: 0.1086 - val_loss: 0.1761
# Epoch 52/100
# 11/11 [==============================] - 7s 661ms/step - loss: 0.1435 - val_loss: 0.2001
# Epoch 53/100
# 11/11 [==============================] - 7s 663ms/step - loss: 0.1336 - val_loss: 0.1963
# Epoch 54/100
# 11/11 [==============================] - 7s 660ms/step - loss: 0.1173 - val_loss: 0.2765
# Epoch 55/100
# 11/11 [==============================] - 7s 662ms/step - loss: 0.1330 - val_loss: 0.1973
# Epoch 56/100
# 11/11 [==============================] - 7s 660ms/step - loss: 0.1236 - val_loss: 0.1836
# Epoch 57/100
# 11/11 [==============================] - 7s 664ms/step - loss: 0.1150 - val_loss: 0.1519
# Epoch 58/100
# 11/11 [==============================] - 7s 660ms/step - loss: 0.1280 - val_loss: 0.1574
# Epoch 59/100
# 11/11 [==============================] - 8s 685ms/step - loss: 0.1170 - val_loss: 0.1650
# Epoch 60/100
# 11/11 [==============================] - 8s 710ms/step - loss: 0.1292 - val_loss: 0.1673
# Epoch 61/100
# 11/11 [==============================] - 8s 723ms/step - loss: 0.1204 - val_loss: 0.1920
# Epoch 62/100
# 11/11 [==============================] - 8s 702ms/step - loss: 0.1019 - val_loss: 0.1722
# Epoch 63/100
# 11/11 [==============================] - 8s 718ms/step - loss: 0.1145 - val_loss: 0.1764
# Epoch 64/100
# 11/11 [==============================] - 8s 719ms/step - loss: 0.1193 - val_loss: 0.1772
# Epoch 65/100
# 11/11 [==============================] - 8s 667ms/step - loss: 0.1093 - val_loss: 0.1502
# Epoch 66/100
# 11/11 [==============================] - 8s 693ms/step - loss: 0.1241 - val_loss: 0.1762
# Epoch 67/100
# 11/11 [==============================] - 8s 682ms/step - loss: 0.1080 - val_loss: 0.1656
# Epoch 68/100
# 11/11 [==============================] - 8s 673ms/step - loss: 0.1204 - val_loss: 0.1624
# Epoch 69/100
# 11/11 [==============================] - 8s 713ms/step - loss: 0.1116 - val_loss: 0.1535
# Epoch 70/100
# 11/11 [==============================] - 8s 720ms/step - loss: 0.1170 - val_loss: 0.1655
# Epoch 71/100
# 11/11 [==============================] - 8s 700ms/step - loss: 0.1267 - val_loss: 0.2715
# Epoch 72/100
# 11/11 [==============================] - 8s 690ms/step - loss: 0.1329 - val_loss: 0.2213
# Epoch 73/100
# 11/11 [==============================] - 8s 720ms/step - loss: 0.1009 - val_loss: 0.2118
# Epoch 74/100
# 11/11 [==============================] - 8s 727ms/step - loss: 0.1262 - val_loss: 0.2099
# Epoch 75/100
# 11/11 [==============================] - 8s 720ms/step - loss: 0.1305 - val_loss: 0.2111
# Epoch 76/100
# 11/11 [==============================] - 8s 720ms/step - loss: 0.1353 - val_loss: 0.1728
# Epoch 77/100
# 11/11 [==============================] - 8s 723ms/step - loss: 0.1180 - val_loss: 0.1647
# Epoch 78/100
# 11/11 [==============================] - 8s 703ms/step - loss: 0.1312 - val_loss: 0.1467
# Epoch 79/100
# 11/11 [==============================] - 8s 704ms/step - loss: 0.1243 - val_loss: 0.1613
# Epoch 80/100
# 11/11 [==============================] - 8s 698ms/step - loss: 0.1114 - val_loss: 0.1502
# Epoch 81/100
# 11/11 [==============================] - 8s 729ms/step - loss: 0.1047 - val_loss: 0.1396
# Epoch 82/100
# 11/11 [==============================] - 8s 710ms/step - loss: 0.1009 - val_loss: 0.1554
# Epoch 83/100
# 11/11 [==============================] - 8s 711ms/step - loss: 0.0954 - val_loss: 0.1507
# Epoch 84/100
# 11/11 [==============================] - 8s 721ms/step - loss: 0.1043 - val_loss: 0.1419
# Epoch 85/100
# 11/11 [==============================] - 8s 732ms/step - loss: 0.0988 - val_loss: 0.1615
# Epoch 86/100
# 11/11 [==============================] - 8s 719ms/step - loss: 0.1139 - val_loss: 0.1466
# Epoch 87/100
# 11/11 [==============================] - 8s 710ms/step - loss: 0.0985 - val_loss: 0.1830
# Epoch 88/100
# 11/11 [==============================] - 8s 705ms/step - loss: 0.1289 - val_loss: 0.1780
# Epoch 89/100
# 11/11 [==============================] - 8s 718ms/step - loss: 0.1165 - val_loss: 0.1335
# Epoch 90/100
# 11/11 [==============================] - 8s 707ms/step - loss: 0.1250 - val_loss: 0.1759
# Epoch 91/100
# 11/11 [==============================] - 8s 665ms/step - loss: 0.1041 - val_loss: 0.1819
# Epoch 92/100
# 11/11 [==============================] - 8s 665ms/step - loss: 0.1075 - val_loss: 0.2089
# Epoch 93/100
# 11/11 [==============================] - 8s 680ms/step - loss: 0.1305 - val_loss: 0.1639
# Epoch 94/100
# 11/11 [==============================] - 8s 668ms/step - loss: 0.1082 - val_loss: 0.1275
# Epoch 95/100
# 11/11 [==============================] - 8s 666ms/step - loss: 0.0917 - val_loss: 0.1408
# Epoch 96/100
# 11/11 [==============================] - 7s 657ms/step - loss: 0.0992 - val_loss: 0.1238
# Epoch 97/100
# 11/11 [==============================] - 8s 725ms/step - loss: 0.1058 - val_loss: 0.1344
# Epoch 98/100
# 11/11 [==============================] - 8s 729ms/step - loss: 0.0996 - val_loss: 0.1210
# Epoch 99/100
# 11/11 [==============================] - 8s 724ms/step - loss: 0.1300 - val_loss: 0.1266
# Epoch 100/100
# 11/11 [==============================] - 8s 725ms/step - loss: 0.1001 - val_loss: 0.1738

# %%
def calculate_iou_score(target, prediction):
    intersection = np.logical_and(target, prediction)
    union = np.logical_or(target, prediction)
    iou_score = float(np.sum(intersection)) / float(np.sum(union))
    print('IoU : %f' % iou_score )
    return iou_score

# %%
def get_output(model, preproc, image_path, output_path, label_path):
    origin_img = imread(image_path)
    data = {"image":origin_img}
    processed = preproc(**data)
    output = model(np.expand_dims(processed["image"]/255,axis=0))
    output = (output[0].numpy()>=0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
    prediction = output/255   # 도로로 판단한 영역
    
    output = Image.fromarray(output)
    background = Image.fromarray(origin_img).convert('RGBA')
    output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
    output = Image.blend(background, output, alpha=0.5)
    output.show()   # 도로로 판단한 영역을 시각화!
     
    if label_path:   
        label_img = imread(label_path)
        label_data = {"image":label_img}
        label_processed = preproc(**label_data)
        label_processed = label_processed["image"]
        target = (label_processed == 7).astype(np.uint8)*1   # 라벨에서 도로로 기재된 영역

        return output, prediction, target
    else:
        return output, prediction, _

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# IoU : 0.864663
# 0.8646632268860689

# %% [markdown]
# # Nest_Net

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)
        
train_generator = KittiGenerator(
    dir_path,
    batch_size=4,
    augmentation=augmentation,
)

test_generator = KittiGenerator(
    dir_path, 
    augmentation=test_preproc,
    is_train=False
)

# %%
def conv_unit(inputs, filters):
    
    conv2d = Conv2D(filters, 3, activation='relu', padding='same',kernel_initializer='he_normal')(inputs)
    conv2d = Conv2D(filters, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv2d)
    
    return conv2d

# %%
from keras.regularizers import l2

def uppnet_build_model(input_shape=(224, 224, 3), num_class=1):
    
    # UNet++L1
    inputs = Input(input_shape)
    conv_x00 = conv_unit(inputs, 64)
    
    pool_x10 = MaxPooling2D(pool_size=(2, 2))(conv_x00)
    conv_x10 = conv_unit(pool_x10, 128)
    
    upsm_x01 = Conv2DTranspose(64, 2, strides=(2, 2))(conv_x10)
    cnct_x01 = Concatenate(axis=3)([upsm_x01, conv_x00])
    conv_x01 = conv_unit(cnct_x01, 64)  
    
    # UNet++L2
    pool_x20 = MaxPooling2D(pool_size=(2, 2))(conv_x10)
    conv_x20 = conv_unit(pool_x20, 256)
    
    upsm_x11 = Conv2DTranspose(128, 2, strides=(2, 2))(conv_x20)
    cnct_x11 = Concatenate(axis=3)([upsm_x11, conv_x10])
    conv_x11 = conv_unit(cnct_x11, 128)  
   
    upsm_x02 = Conv2DTranspose(64, 2, strides=(2, 2))(conv_x11)
    cnct_x02 = Concatenate(axis=3)([upsm_x02, conv_x01, conv_x00])
    conv_x02 = conv_unit(cnct_x02, 64)  
    
    # UNet++L3
    pool_x30 = MaxPooling2D(pool_size=(2, 2))(conv_x20)
    conv_x30 = conv_unit(pool_x30, 512)
    
    upsm_x21 = Conv2DTranspose(256, 2, strides=(2, 2))(conv_x30)
    cnct_x21 = Concatenate(axis=3)([upsm_x21, conv_x20])
    conv_x21 = conv_unit(cnct_x21, 256)  
   
    upsm_x12 = Conv2DTranspose(128, 2, strides=(2, 2))(conv_x21)
    cnct_x12 = Concatenate(axis=3)([upsm_x12, conv_x11, conv_x10])
    conv_x12 = conv_unit(cnct_x12, 128)
    
    upsm_x03 = Conv2DTranspose(64, 2, strides=(2, 2))(conv_x12)
    cnct_x03 = Concatenate(axis=3)([upsm_x03, conv_x02, conv_x01, conv_x00])
    conv_x03 = conv_unit(cnct_x03, 64)     
    
    # UNet++L4
    pool_x40 = MaxPooling2D(pool_size=(2, 2))(conv_x30)
    conv_x40 = conv_unit(pool_x40, 1024)
    
    upsm_x31 = Conv2DTranspose(512, 2, strides=(2, 2))(conv_x40)
    cnct_x31 = Concatenate(axis=3)([upsm_x31, conv_x30])
    conv_x31 = conv_unit(cnct_x31, 512)  
   
    upsm_x22 = Conv2DTranspose(256, 2, strides=(2, 2))(conv_x31)
    cnct_x22 = Concatenate(axis=3)([upsm_x22, conv_x21, conv_x20])
    conv_x22 = conv_unit(cnct_x22, 256)
    
    upsm_x13 = Conv2DTranspose(128, 2, strides=(2, 2))(conv_x22)
    cnct_x13 = Concatenate(axis=3)([upsm_x13, conv_x12, conv_x11, conv_x10])
    conv_x13 = conv_unit(cnct_x13, 128)       

    upsm_x04 = Conv2DTranspose(64, 2, strides=(2, 2))(conv_x13)
    cnct_x04 = Concatenate(axis=3)([upsm_x04, conv_x03,conv_x02, conv_x01, conv_x00])
    conv_x04 = conv_unit(cnct_x04, 64)
    
    UppNet_Output = Conv2D(num_class, (1, 1), activation='sigmoid', name='output_4', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv_x04)
    
    
    model = Model(inputs = inputs, outputs = UppNet_Output)
    return model

model = uppnet_build_model()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 224, 224, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 224, 224, 64) 36928       conv2d_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 112, 112, 64) 0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 112, 112, 128 73856       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 112, 112, 128 147584      conv2d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 56, 56, 128)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 56, 56, 256)  295168      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 28, 28, 256)  0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 28, 28, 512)  1180160     max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 28, 28, 512)  2359808     conv2d_36[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 1024) 4719616     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 1024) 9438208     conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 28, 28, 512)  2097664     conv2d_45[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 28, 28, 1024) 0           conv2d_transpose_6[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 56, 56, 256)  524544      conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 28, 28, 512)  4719104     concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 56, 56, 512)  0           conv2d_transpose_3[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 112, 112, 128 131200      conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 28, 28, 512)  2359808     conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 56, 56, 256)  1179904     concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 112, 112, 256 0           conv2d_transpose_1[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 224, 224, 64) 32832       conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 56, 56, 256)  524544      conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 112, 112, 128 295040      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 224, 224, 128 0           conv2d_transpose[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 56, 56, 768)  0           conv2d_transpose_7[0][0]
#                                                                  conv2d_39[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 112, 112, 128 131200      conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 112, 112, 128 147584      conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 224, 224, 64) 73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 56, 56, 256)  1769728     concatenate_11[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 112, 112, 384 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 224, 224, 64) 32832       conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 224, 224, 64) 36928       conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 112, 112, 128 442496      concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 224, 224, 192 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 112, 112, 128 131200      conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 112, 112, 128 147584      conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 224, 224, 64) 110656      concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 112, 112, 512 0           conv2d_transpose_8[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 224, 224, 64) 32832       conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 224, 224, 64) 36928       conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 112, 112, 128 589952      concatenate_12[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 224, 224, 256 0           conv2d_transpose_5[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 112, 112, 128 147584      conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 224, 224, 64) 147520      concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 224, 224, 64) 32832       conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 224, 224, 64) 36928       conv2d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 224, 224, 320 0           conv2d_transpose_9[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 224, 224, 64) 184384      concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 224, 224, 64) 36928       conv2d_52[0][0]
# __________________________________________________________________________________________________
# output_4 (Conv2D)               (None, 224, 224, 1)  65          conv2d_53[0][0]
# ==================================================================================================
# Total params: 36,157,953
# Trainable params: 36,157,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy')
model.fit_generator(
     generator=train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

model_path = dir_path + '/seg_model_uppnet_unet.h5'
model.save(model_path)  #학습한 모델을 저장해 주세요.
# Out:
# Epoch 1/100
# 43/43 [==============================] - 77s 575ms/step - loss: 0.6060 - val_loss: 0.3539
# Epoch 2/100
# 43/43 [==============================] - 17s 392ms/step - loss: 0.3132 - val_loss: 0.3421
# Epoch 3/100
# 43/43 [==============================] - 17s 393ms/step - loss: 0.2739 - val_loss: 0.3183
# Epoch 4/100
# 43/43 [==============================] - 17s 393ms/step - loss: 0.2142 - val_loss: 0.2578
# Epoch 5/100
# 43/43 [==============================] - 17s 395ms/step - loss: 0.2173 - val_loss: 0.2764
# Epoch 6/100
# 43/43 [==============================] - 17s 392ms/step - loss: 0.2263 - val_loss: 0.3354
# Epoch 7/100
# 43/43 [==============================] - 17s 391ms/step - loss: 0.1876 - val_loss: 0.2296
# Epoch 8/100
# 43/43 [==============================] - 17s 392ms/step - loss: 0.2071 - val_loss: 0.2848
# Epoch 9/100
# 43/43 [==============================] - 17s 392ms/step - loss: 0.1706 - val_loss: 0.3104
# Epoch 10/100
# 43/43 [==============================] - 17s 391ms/step - loss: 0.1931 - val_loss: 0.1953
# Epoch 11/100
# 43/43 [==============================] - 17s 392ms/step - loss: 0.2184 - val_loss: 0.3684
# Epoch 12/100
# 43/43 [==============================] - 17s 391ms/step - loss: 0.1994 - val_loss: 0.3384
# Epoch 13/100
# 43/43 [==============================] - 17s 391ms/step - loss: 0.1521 - val_loss: 0.2424
# Epoch 14/100
# 43/43 [==============================] - 17s 397ms/step - loss: 0.1778 - val_loss: 0.3067
# Epoch 15/100
# 43/43 [==============================] - 17s 392ms/step - loss: 0.2055 - val_loss: 0.2262
# Epoch 16/100
# 43/43 [==============================] - 17s 392ms/step - loss: 0.1569 - val_loss: 0.2963
# Epoch 17/100
# 43/43 [==============================] - 19s 446ms/step - loss: 0.1524 - val_loss: 0.2380
# Epoch 18/100
# 43/43 [==============================] - 22s 518ms/step - loss: 0.1858 - val_loss: 0.2100
# Epoch 19/100
# 43/43 [==============================] - 22s 507ms/step - loss: 0.1593 - val_loss: 0.2890
# Epoch 20/100
# 43/43 [==============================] - 18s 414ms/step - loss: 0.1654 - val_loss: 0.2713
# Epoch 21/100
# 43/43 [==============================] - 18s 416ms/step - loss: 0.1755 - val_loss: 0.2685
# Epoch 22/100
# 43/43 [==============================] - 18s 412ms/step - loss: 0.1526 - val_loss: 0.1805
# Epoch 23/100
# 43/43 [==============================] - 17s 398ms/step - loss: 0.1480 - val_loss: 0.2204
# Epoch 24/100
# 43/43 [==============================] - 18s 410ms/step - loss: 0.1423 - val_loss: 0.2247
# Epoch 25/100
# 43/43 [==============================] - 17s 394ms/step - loss: 0.1619 - val_loss: 0.1978
# Epoch 26/100
# 43/43 [==============================] - 16s 374ms/step - loss: 0.1487 - val_loss: 0.2167
# Epoch 27/100
# 43/43 [==============================] - 16s 366ms/step - loss: 0.1614 - val_loss: 0.1978
# Epoch 28/100
# 43/43 [==============================] - 16s 378ms/step - loss: 0.1641 - val_loss: 0.1775
# Epoch 29/100
# 43/43 [==============================] - 16s 375ms/step - loss: 0.1232 - val_loss: 0.1705
# Epoch 30/100
# 43/43 [==============================] - 16s 375ms/step - loss: 0.1500 - val_loss: 0.2198
# Epoch 31/100
# 43/43 [==============================] - 16s 377ms/step - loss: 0.1241 - val_loss: 0.2239
# Epoch 32/100
# 43/43 [==============================] - 16s 367ms/step - loss: 0.1130 - val_loss: 0.2462
# Epoch 33/100
# 43/43 [==============================] - 16s 361ms/step - loss: 0.1602 - val_loss: 0.1956
# Epoch 34/100
# 43/43 [==============================] - 16s 369ms/step - loss: 0.1306 - val_loss: 0.1890
# Epoch 35/100
# 43/43 [==============================] - 16s 382ms/step - loss: 0.1738 - val_loss: 0.2154
# Epoch 36/100
# 43/43 [==============================] - 17s 393ms/step - loss: 0.1248 - val_loss: 0.2390
# Epoch 37/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1458 - val_loss: 0.2029
# Epoch 38/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1190 - val_loss: 0.2271
# Epoch 39/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1449 - val_loss: 0.1878
# Epoch 40/100
# 43/43 [==============================] - 17s 389ms/step - loss: 0.1495 - val_loss: 0.1712
# Epoch 41/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1165 - val_loss: 0.1955
# Epoch 42/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1049 - val_loss: 0.1670
# Epoch 43/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1073 - val_loss: 0.1914
# Epoch 44/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1138 - val_loss: 0.1867
# Epoch 45/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1254 - val_loss: 0.1851
# Epoch 46/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1127 - val_loss: 0.2115
# Epoch 47/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1111 - val_loss: 0.1909
# Epoch 48/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1272 - val_loss: 0.1902
# Epoch 49/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1282 - val_loss: 0.2026
# Epoch 50/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1127 - val_loss: 0.1742
# Epoch 51/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.0974 - val_loss: 0.1588
# Epoch 52/100
# 43/43 [==============================] - 17s 388ms/step - loss: 0.1314 - val_loss: 0.2272
# Epoch 53/100
# 43/43 [==============================] - 17s 395ms/step - loss: 0.1028 - val_loss: 0.1868
# Epoch 54/100
# 43/43 [==============================] - 16s 369ms/step - loss: 0.1181 - val_loss: 0.1520
# Epoch 55/100
# 43/43 [==============================] - 16s 366ms/step - loss: 0.1101 - val_loss: 0.2119
# Epoch 56/100
# 43/43 [==============================] - 15s 355ms/step - loss: 0.1203 - val_loss: 0.1955
# Epoch 57/100
# 43/43 [==============================] - 15s 348ms/step - loss: 0.1152 - val_loss: 0.1870
# Epoch 58/100
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0973 - val_loss: 0.2180
# Epoch 59/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.1073 - val_loss: 0.1533
# Epoch 60/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.1048 - val_loss: 0.1966
# Epoch 61/100
# 43/43 [==============================] - 16s 378ms/step - loss: 0.1091 - val_loss: 0.1759
# Epoch 62/100
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0976 - val_loss: 0.1408
# Epoch 63/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.1036 - val_loss: 0.1663
# Epoch 64/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.1159 - val_loss: 0.1962
# Epoch 65/100
# 43/43 [==============================] - 16s 381ms/step - loss: 0.1191 - val_loss: 0.1421
# Epoch 66/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0990 - val_loss: 0.1569
# Epoch 67/100
# 43/43 [==============================] - 16s 380ms/step - loss: 0.1128 - val_loss: 0.1425
# Epoch 68/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0812 - val_loss: 0.1487
# Epoch 69/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.1124 - val_loss: 0.1563
# Epoch 70/100
# 43/43 [==============================] - 16s 380ms/step - loss: 0.0940 - val_loss: 0.1650
# Epoch 71/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0981 - val_loss: 0.1695
# Epoch 72/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0833 - val_loss: 0.2713
# Epoch 73/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0922 - val_loss: 0.1867
# Epoch 74/100
# 43/43 [==============================] - 16s 380ms/step - loss: 0.1228 - val_loss: 0.1266
# Epoch 75/100
# 43/43 [==============================] - 16s 380ms/step - loss: 0.0984 - val_loss: 0.1361
# Epoch 76/100
# 43/43 [==============================] - 16s 380ms/step - loss: 0.0864 - val_loss: 0.1391
# Epoch 77/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0758 - val_loss: 0.2084
# Epoch 78/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0976 - val_loss: 0.1288
# Epoch 79/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0919 - val_loss: 0.1571
# Epoch 80/100
# 43/43 [==============================] - 16s 380ms/step - loss: 0.0875 - val_loss: 0.1704
# Epoch 81/100
# 43/43 [==============================] - 16s 380ms/step - loss: 0.0931 - val_loss: 0.1502
# Epoch 82/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0829 - val_loss: 0.1439
# Epoch 83/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0816 - val_loss: 0.2657
# Epoch 84/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0965 - val_loss: 0.1985
# Epoch 85/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.1087 - val_loss: 0.1306
# Epoch 86/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0983 - val_loss: 0.1400
# Epoch 87/100
# 43/43 [==============================] - 16s 382ms/step - loss: 0.0836 - val_loss: 0.1275
# Epoch 88/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0971 - val_loss: 0.2038
# Epoch 89/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0869 - val_loss: 0.1915
# Epoch 90/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0746 - val_loss: 0.1564
# Epoch 91/100
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0812 - val_loss: 0.1674
# Epoch 92/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0816 - val_loss: 0.1144
# Epoch 93/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0864 - val_loss: 0.1344
# Epoch 94/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0897 - val_loss: 0.1205
# Epoch 95/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0839 - val_loss: 0.1870
# Epoch 96/100
# 43/43 [==============================] - 16s 380ms/step - loss: 0.0872 - val_loss: 0.1362
# Epoch 97/100
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0960 - val_loss: 0.1884
# Epoch 98/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0807 - val_loss: 0.1341
# Epoch 99/100
# 43/43 [==============================] - 16s 380ms/step - loss: 0.0877 - val_loss: 0.2072
# Epoch 100/100
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0881 - val_loss: 0.1763

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# IoU : 0.929252
# 0.929252308608877

# %% [markdown]
# # 프로젝트를 마치며...
