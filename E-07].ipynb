# %% [markdown]
# # 프로젝트 : 나랑 닮은 연예인을 찾아보자.

# %% [markdown]
# ### Step1. 사진 모으기

# %% [markdown]
# ### Step2. 얼굴 영역 자르기

# %% [markdown]
# ### 임베딩 추출을 위해서는 얼굴 영역을 잘라줘야 합니다. 위 Step1.에서 찾은 이미지들을 이전에 만들었던 get_gropped_face(image_file)을 통해서 잘라줍시다! 자른 이미지는 PIL의 Image.fromarray를 통해서 PIL Image로 변환한 뒤에 저장을 해두면 다양한 재미있는 시각화를 시도해 보는 데 도움이 될 것입니다.

# %%
import face_recognition
import os

image_path = os.getenv('HOME')+'/aiffel/face_embedding/images2/zoo1.jpg'
image = face_recognition.load_image_file(image_path)
face_locations = face_recognition.face_locations(image)

print(face_locations)  # 이미지에서 얼굴 영역의 좌표를 출력합니다.

# %matplotlib inline
import matplotlib.pyplot as plt

a, b, c, d = face_locations[0]
cropped_face = image[a:c,d:b,:]

plt.imshow(cropped_face)   # 이미지에서 얼굴영역만 잘라낸 cropped_face를 그려 봅니다.
# Out:
# [(36, 201, 222, 15)]

# %%
import face_recognition
import os

def get_gropped_face(image_file):
    image = face_recognition.load_image_file(image_file)
    face_locations = face_recognition.face_locations(image)
    a, b, c, d = face_locations[0]
    cropped_face = image[a:c,d:b,:]
      
    return cropped_face

# %%
image_path = os.getenv('HOME')+'/aiffel/face_embedding/images2/혜리.jpeg'

cropped_face = get_gropped_face(image_path)
plt.imshow(cropped_face)

# %%
# from PIL import Image
# face = get_gropped_face(image_path)
# pillow_image = Image.fromarray(face)
# pillow_image.save(path_to_save)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-bd79eff0a10a> in <module>
#       2 face = get_gropped_face(image_path)
#       3 pillow_image = Image.fromarray(face)
# ----> 4 pillow_image.save(path_to_save)
#
# NameError: name 'path_to_save' is not defined

# %% [markdown]
# ##    힌트
# ##    from PIL import Image
# ##    face = get_gropped_face(image_path)
# ##    pillow_image = Image.fromarray(face)
# ##    pillow_image.save(path_to_save)

# %% [markdown]
# ### Step3. 얼굴 영역의 임베딩 추출하기

# %% [markdown]
# 이제 얼굴 영역으로 잘린 이미지들이 여럿 생겼을 텐데요. 그 이미지를 face_recognition 을 사용해서 이미지를 불러오고 임베딩을 추출해 봅시다. 다른 사람의 임베딩은 구분할 수 있게 따로 저장해 주세요. 이전에 만들었던 다음 함수들을 활용하면 손쉽게 수행 가능합니다.
#
# def get_face_embedding(face) : 얼굴영역으로부터 얼굴 임베딩 벡터를 구하는 함수
# def get_face_embedding_dict(dir_path) : 디렉토리 안에 있는 모든 이미지의 임베딩 딕셔너리를 구하는 함수

# %%
import os

dir_path = os.getenv('HOME')+'/aiffel/face_embedding/images2'
file_list = os.listdir(dir_path)

print ("file_list: {}".format(file_list)) #디렉토리에 있는 파일들 읽기
# Out:
케이.jpg', '톰 홀랜드.jpg', '슬리피.jpg', '잇섭.png', '조달환.png', '김희철.jpg', '박항서.jpg', '서강준.jpg', '트와이스나연.jpg', '지디.jpg', '이정재.jpeg', '성시경.jpg', '김영삼.jpeg', '박휘순.jpg', '신동엽.jpg', '백현.jpg', '화사.jpg', '류승룡.jpeg', '손흥민.jpg', '지드래곤.jpeg', '곽도원.jpg', '문재인.jpeg', '윤아.jpg', '박신양.png', '이동휘.jpg', '유희열.jpeg', '비니.jpg', '찬열.jpeg', '장동건.jpeg', '딕헌터.jpeg', '박완규.png', 'zoo2.jpg', '이준혁.jpeg', '공효진.jpg', '윤균상.jpg', '윤종신.jpeg', '목진화.png', '온앤오프효진.jpg', '사쿠라.jpg', '소지섭3.jpeg', '마동석.jpeg', '유아.jpg', '야마다 타카유키.jpeg', '유노윤호.jpg', '유지태.jpg', '줄리엔강.png', '레인보우재경.jpg', '장도연.jpg', '박정민.jpg', '브래들리 쿠퍼.jpg', '하현우.jpg', '조승우.jpeg', '제이홉.jpg', '박희순.jpg', '박재범.jpg', '김고은.jpeg', '김대중.jpg', '심수창.jpeg', '이승기.jpeg', '로다주.jpeg', '솔라.jpg', '잭 블랙.jpeg', '이범수.jpeg', '김현수.jpeg', '김구라.jpg', '잭 스페이더.jpeg', '트와이스미나.jpg', '박명수.jpg', '사무엘 L 잭슨.jpg', '도아.jpeg', '돈스파이크.jpg', '최민식.jpg', '제이콥 배털론.jpg', '박보영.jpg', '박나래.jpeg', '개리.jpg', '저스틴 존슨.jpeg', '홍구.jpg', '류진.jpg', '마크 러팔로.jpeg', '공유.jpg', '이연걸.jpeg', '케빈 스페이시.jpeg', '도지한.jpg', '러블리즈지수.jpeg', '개코.jpeg', '박진영.jpeg', '태연.jpg', '안재홍.jpg', '이민호.jpeg', '이대호.jpeg', '레오나르도 디카프리오.jpeg', '조정치.jpg', '첸.jpg', '류현진.jpg', '길.jpg', '기성용.jpg', '방시혁.jpeg', '서현진.jpg', '이명박.jpg', '차승원.jpg', '이진호.jpeg', '대도서관.jpeg', '류승범.jpg', '성룡.jpg', 'zoo.jpg', '앤드류 응.png', '주호민.jpeg', '이제훈.jpeg', '강동원.jpg', '하정우.jpg', '하승진.jpg', 'b1a4진영.jpeg', 'bush.jpeg', '우기.jpg', 'biden.jpg', '소지섭.jpeg', '박보검.jpg', '유리.jpg', '이영하.jpg', '김유정.jpg', '박건우.png', '김광현.jpg', 'trump.jpg', '이경규.jpeg', '수호.jpg']

# %%
image_file = os.path.join(dir_path, '혜리.jpeg')
face = get_gropped_face(image_file)   # 얼굴 영역을 구하는 함수(이전 스텝에서 구현)

# 얼굴 영역을 가지고 얼굴 임베딩 벡터를 구하는 함수
def get_face_embedding(face):
    return face_recognition.face_encodings(face)

embedding = get_face_embedding(face)  
embedding
# Out:
# []

# %%
def get_face_embedding_dict(dir_path):
    file_list = os.listdir(dir_path)
    embedding_dict = {}

    for file in file_list:
        img_path = os.path.join(dir_path, file)
        face = get_gropped_face(img_path)
        embedding = get_face_embedding(face)
        if len(embedding) > 0:  # 얼굴영역 face가 제대로 detect되지 않으면  len(embedding)==0인 경우가 발생하므로 
                    # os.path.splitext(file)[0]에는 이미지파일명에서 확장자를 제거한 이름이 담깁니다. 
            embedding_dict[os.path.splitext(file)[0]] = embedding[0]

    return embedding_dict

# %%
# def get_face_embedding_dict(dir_path):
#     file_list = os.listdir(dir_path)
#     embedding_dict = {}

#     for file in file_list:
#         img_path = os.path.join(dir_path, file)
#         face = get_gropped_face(img_path)
#         embedding = get_face_embedding(face)
#         if len(embedding) > 0:  # 얼굴영역 face가 제대로 detect되지 않으면  len(embedding)==0인 경우가 발생하므로 
#                     # os.path.splitext(file)[0]에는 이미지파일명에서 확장자를 제거한 이름이 담깁니다. 
#             embedding_dict[os.path.splitext(file)[0]] = embedding[0]
#         if len(face) == 0:
#             continue #얼굴 인식 실패시 추가 안함
            
            
#     return embedding_dict

# %%
embedding_dict = get_face_embedding_dict(dir_path)
embedding_dict['혜리']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-be14bfa1be1d> in <module>
# ----> 1 embedding_dict = get_face_embedding_dict(dir_path)
#       2 embedding_dict['혜리']
#
# <ipython-input-27-55e6a999afa0> in get_face_embedding_dict(dir_path)
#       5     for file in file_list:
#       6         img_path = os.path.join(dir_path, file)
# ----> 7         face = get_gropped_face(img_path)
#       8         embedding = get_face_embedding(face)
#       9         if len(embedding) > 0:  # 얼굴영역 face가 제대로 detect되지 않으면  len(embedding)==0인 경우가 발생하므로
#
# <ipython-input-23-c8386b729c00> in get_gropped_face(image_file)
#       5     image = face_recognition.load_image_file(image_file)
#       6     face_locations = face_recognition.face_locations(image)
# ----> 7     a, b, c, d = face_locations[0]
#       8     cropped_face = image[a:c,d:b,:]
#       9
#
# IndexError: list index out of range

# %% [markdown]
# ### Step4. 모은 연예인들과 비교하기

# %% [markdown]
# 모은 연예인 사진들과 자신의 얼굴 사진에서 추출한 임베딩 벡터들 간의 거리를 비교해 보고 가장 작은 연예인이 누구인지 찾아봅시다!
#
# 이전 스텝에서 만들었던 get_nearest_face(name, top=5) 함수들을 응용하면 손쉽게 수행 가능합니다.

# %%
def get_nearest_face(name, top=5):
    sort_key_func = get_sort_key_func(name)
    sorted_faces = sorted(embedding_dict.items(), key=lambda x:sort_key_func(x[0]))

    for i in range(top+1):
        if i == 0 :   # 첫번째로 나오는 이름은 자기 자신일 것이므로 제외합시다. 
            continue
        if sorted_faces[i]:
            print('순위 {} : 이름({}), 거리({})'.format(i, sorted_faces[i][0], sort_key_func(sorted_faces[i][0])))

# %%
# zoo와 가장 닮은 사람은 누굴까요?
get_nearest_face('zoo')

# %% [markdown]
# ### Step5. 다양한 재미있는 시각화 시도해 보기

# %% [markdown]
# 비단 닮은 꼴 연예인을 찾기만 할 것이 아니라, 그들의 얼굴 사진을 활용하여 재미있는 시각화를 시도해 보시기 바랍니다.
# tkinter나 flask를 활용해서 닮은꼴을 찾을 이미지를 업로드한 후 그 이미지와 닮은 얼굴을 찾는 형태로 구현해 보는 것도 재미있을 것입니다.
# 여러분들의 재치가 넘치는 작품들을 기대합니다. 😎
